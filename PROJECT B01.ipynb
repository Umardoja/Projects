# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
report = pd.read_csv('world-happiness-report-2021.csv')

# %%
report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
report.drop(columns = {'Freedom to make life choices','Generosity','Perceptions of corruption','Ladder score in Dystopia','Logged GDP per capita','Social support','Healthy life expectancy'},inplace  = True)

# %%
report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# ...

# %%
report['Summarized Happiness'] = report['Explained by: Perceptions of corruption'] + report['Explained by: Generosity']+report['Explained by: Healthy life expectancy'] + report['Explained by: Freedom to make life choices']+ report['Explained by: Social support'] + report['Explained by: Log GDP per capita']

# %%
report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# ...

# %%
report['tot_rank'] = report['Summarized Happiness'].rank( ascending= False)

# %%
report.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                             1.446                         1.106
# 1                             1.502                         1.108
# 2                             1.566                         1.079
# ...

# %%
Question1 = report[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Summarized Happiness  tot_rank
# 115                 2.023     127.0

# %%
report[18:19]
# Out:
#      Country name     Regional indicator  Ladder score  \
# 18  United States  North America and ANZ         6.951
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 18                           0.049         7.047         6.856
#
#     Explained by: Log GDP per capita  Explained by: Social support  \
# 18                             1.533                          1.03
#
#     Explained by: Healthy life expectancy  \
# 18                                  0.621
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 18                                       0.554                     0.252
#
#     Explained by: Perceptions of corruption  Dystopia + residual  \
# 18                                    0.154                2.807
#
#     Summarized Happiness  tot_rank
# 18                 4.144      20.0

# %%
report[115:116]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 115      Nigeria  Sub-Saharan Africa         4.759
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 115                           0.052         4.861         4.658
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 115                             0.663                         0.625
#
#      Explained by: Healthy life expectancy  \
# 115                                  0.051
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 115                                       0.433                     0.212
#
#      Explained by: Perceptions of corruption  Dystopia + residual  \
# 115                                    0.039                2.736
#
#      Summarized Happiness  tot_rank
# 115                 2.023     127.0

# %%
index_names = ['1','2']
rep ={'Summarized Happiness': [4.144, 2.023],'Country':['United States','Nigeria']}

# %%
reports = pd.DataFrame(rep)

# %%
Question2 = reports
# Out:
#    Summarized Happiness        Country
# 0                 4.144  United States
# 1                 2.023        Nigeria

# %%
fig = plt.figure(figsize=(10,6),)
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_title('LEVEL OF HAPPINESS')

sn = sns.barplot(reports['Country'],reports['Summarized Happiness'],estimator=max,palette='magma')
plt.setp(sn.get_xticklabels(),rotation=45)
plt.show()
plt.tight_layout()

# %%
sns.lmplot(x='Ladder score',y='Summarized Happiness',data=report)

sns.lmplot(x='upperwhisker',y='Summarized Happiness',data=report)

sns.lmplot(x='lowerwhisker',y='Summarized Happiness',data=report)

# %%
report.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual', 'Summarized Happiness', 'tot_rank'],
#       dtype='object')

# %%
X = report.drop(['Regional indicator','Country name','Summarized Happiness'],axis=1)
y = report['Summarized Happiness']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X[144:156]
# Out:
#      Ladder score  Standard error of ladder score  upperwhisker  lowerwhisker  \
# 144         3.512                           0.120         3.748         3.276
# 145         3.467                           0.074         3.611         3.322
# 146         3.415                           0.068         3.548         3.282
# 147         3.145                           0.058         3.259         3.030
# 148         2.523                           0.038         2.596         2.449
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 144                             0.451                         0.731
# 145                             1.099                         0.724
# 146                             0.364                         0.202
# 147                             0.457                         0.649
# 148                             0.370                         0.000
#
#      Explained by: Healthy life expectancy  \
# ...

# %%
#Dependent variables are easily used to interprete results

# %%
lr.score(X_test,y_test)
# Out:
# 1.0

# %%
pred = [[0.7591,0.043,7.7,7.523,10.910,0.901,72.001,0.951,0.101,0.177,2.430]]

# %%
Question5 = lr.predict(pred)
